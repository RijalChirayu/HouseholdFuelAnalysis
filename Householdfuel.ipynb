# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# Importing_data

# %%
df = pd.read_excel('cooking.xlsx')

# %%
df
# Out:
#     Table 07: Number of households by type of fuel usually used for cooking, NPHC 2021
# 0                                                  NaN                                  \
# 1                                                 Area
# 2                                                  NaN
# 3                                                  NaN
# 4                                                Nepal
# ..                                                 ...
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
#
#      Unnamed: 1 Unnamed: 2       Unnamed: 3               Unnamed: 4
# 0           NaN        NaN              NaN                      NaN  \
# 1           NaN      Total     Type of fuel                      NaN
# ...

# %% [markdown]
# Droping duplicates

# %%
df.drop_duplicates( inplace = True)

# %%
df
# Out:
#     Table 07: Number of households by type of fuel usually used for cooking, NPHC 2021
# 0                                                  NaN                                  \
# 1                                                 Area
# 2                                                  NaN
# 4                                                Nepal
# 6                                          Urban/Rural
# ..                                                 ...
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
#
#      Unnamed: 1 Unnamed: 2       Unnamed: 3               Unnamed: 4
# 0           NaN        NaN              NaN                      NaN  \
# 1           NaN      Total     Type of fuel                      NaN
# ...

# %%
df.columns
# Out:
# Index(['Table 07: Number of households by type of fuel usually used for cooking, NPHC 2021',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
# ### Renaming the columns

# %%
df.rename(columns={'Table 07: Number of households by type of fuel usually used for cooking, NPHC 2021':'Households by fuel type',
       'Unnamed: 1':'Region', 'Unnamed: 2':'Total', 'Unnamed: 3':'Firewood', 'Unnamed: 4':'LPG', 'Unnamed: 5': 'Electricity',
       'Unnamed: 6' : 'Cow dung', 'Unnamed: 7': 'Bio Gas', 'Unnamed: 8':'Kerosense', 'Unnamed: 9':'Others'} , inplace = True)

# %% [markdown]
# Selecting data without the first column

# %%
data = df.drop(['Households by fuel type'] , axis = 1)

# %% [markdown]
# Selecting Certain Urban and Rural Region

# %%
region_data = data.loc[7:9]
region_data
# Out:
#                  Region    Total Firewood      LPG Electricity Cow dung
# 7  Urban Municipalities  4474699  1759331  2536623       24724    93262  \
# 8  Rural Municipalities  2186142  1638985   413372        7850    98269
#
#   Bio Gas Kerosense Others
# 7   54435      1849   4475
# 8   23971      1448   2247

# %% [markdown]
# Plotting the data for households using Firewood , LPG and Electricity

# %%
region_data.plot(kind='bar' , x = 'Region' , y = ['Firewood' , 'LPG' , 'Electricity'] , stacked= False , rot= 0 , ylabel='No of fuel used (in 10 lakhs) ' , title = 'Fuel used in Rural and Urban region of Nepal')
# Out:
# <Axes: title={'center': 'Fuel used in Rural and Urban region of Nepal'}, xlabel='Region', ylabel='No of fuel used (in 10 lakhs) '>

# %% [markdown]
# ## Districts Household fuel data for descriptive analysis.

# %% [markdown]
# Selecting Districts rows

# %%
district_data = df[20:]
district_data.drop(['Households by fuel type'] , axis = 1 , inplace = True )

# %% [markdown]
# Setting Districts as index

# %%
district_data.set_index('Region' , inplace = True)

# %%
district_data
# Out:
#                 Total  Firewood    LPG  Electricity  Cow dung  Bio Gas
# Region
# Taplejung       27776     24630   3006           32         5       51  \
# Sankhuwasabha   39118     32922   5907           61         3      171
# Solukhumbu      26239     21785   3945          400         1       56
# Okhaldhunga     34286     31285   2724           21         3      216
# Khotang         41720     38030   3351           43         4      241
# ...               ...       ...    ...          ...       ...      ...
# Dadeldhura      31172     27350   3688           27         3       80
# Doti            45140     40584   4313           30         2      126
# Achham          49567     46350   2928           34         1      140
# Kailali        195872    101657  80777          999       281    11902
# Kanchanpur     111167     57452  46036          432       156     7028
#
#                Kerosense  Others
# Region
# Taplejung             21      31
# ...

# %%
district_data.columns
# Out:
# Index(['Total', 'Firewood', 'LPG', 'Electricity', 'Cow dung', 'Bio Gas',
#        'Kerosense', 'Others'],
#       dtype='object')

# %% [markdown]
# Here the columns value are object not integers. Hence, we cannot do analysis without changing the data type

# %% [markdown]
# Changing the data type of columns for discriptive statistics.

# %%
district_data = district_data[['Total', 'Firewood', 'LPG', 'Electricity', 'Cow dung', 'Bio Gas',
       'Kerosense', 'Others']].astype(str).astype(int)

# %%
district_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, Taplejung to Kanchanpur
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Total        77 non-null     int32
#  1   Firewood     77 non-null     int32
#  2   LPG          77 non-null     int32
#  3   Electricity  77 non-null     int32
#  4   Cow dung     77 non-null     int32
#  5   Bio Gas      77 non-null     int32
#  6   Kerosense    77 non-null     int32
#  7   Others       77 non-null     int32
# dtypes: int32(8)
# memory usage: 3.0+ KB

# %% [markdown]
# ### Discriptive analysis for type of fules based on districts

# %%
district_data.describe()
# Out:
#                Total       Firewood            LPG  Electricity      Cow dung
# count      77.000000      77.000000      77.000000    77.000000     77.000000  \
# mean    86504.428571   44133.974026   38311.623377   423.038961   2487.415584
# std     80423.272905   24887.927232   69901.356684   696.420178   7167.881015
# min      1547.000000    1058.000000     133.000000     1.000000      0.000000
# 25%     37453.000000   25782.000000    3688.000000    30.000000      2.000000
# 50%     64991.000000   42743.000000   13830.000000    91.000000      9.000000
# 75%    113013.000000   57020.000000   46036.000000   717.000000    113.000000
# max    542892.000000  109720.000000  526931.000000  4694.000000  44715.000000
#
#             Bio Gas   Kerosense       Others
# count     77.000000   77.000000    77.000000
# mean    1018.259740   42.818182    87.298701
# std     1891.960543   35.592994   195.011677
# min       14.000000    1.000000     1.000000
# ...
